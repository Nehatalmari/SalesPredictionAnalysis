# %% [markdown]
# ## Lets discuss about the outliners in dataset

# %% [markdown]
# ## Actually outliners are the odd one out in the datasets.
# ## We can say they are the extremes values and doesnot sink the dataset values.
#         * SO how do we determine the outliners in the dataset.

# %%
from IPython.display import Image
Image("outlinerimage.jpeg")

# %% [markdown]
# ### so if we look at the above images what can you say about number 3.
# ===== > Rest all the numbers are in between [30,36], but the 3 is not belongs to that caterogery. This is called outliners.

# %%
import seaborn as sns
